# %% [markdown]
# # Eddy Viscosity Models and Solver Review
#
# **Here's a brief review of the solver and the eddy viscosity models:**
#
# -  This notebook includes an eddy viscosity model where the *eddy viscosity coefficient* can be dynamically adjusted.

# %% [markdown]
# ## 2D Turbulence
#
# We solve Eqs. in the vorticity-streamfunction, $\omega-\psi$, formulation, where
#
#
#
# With this formulation, the governing equations are
#
# $$
# \begin{aligned}
# \nabla^2\psi &= - \omega, \tag{1} \\
# \frac{\partial \omega}{\partial t} + \mathcal{N}\left(\omega,\psi\right) &= \frac{1}{Re}\nabla^2\omega -\chi \omega - f + \beta v,
# \end{aligned}
# $$
#
# where $\mathcal{N}(\omega,\psi)$ is
#
# $$
# \mathcal{N}(\omega,\psi) = \frac{\partial \omega}{\partial x}\frac{\partial \psi}{\partial y} - \frac{\partial \omega}{\partial y}\frac{\partial \psi}{\partial x}.
# $$
#
# $f$ is a deterministic forcing \cite{chandler2013invariant, kochkov2021machine}:
#
# $$
# f = f_{k_x}\cos(f_{k_x}x) + f_{k_y}\cos(f_{k_y}y), \tag{4}
# $$
#
# where $f_{k_{x}}$ and $f_{k_{y}}$ are the forcing wavenumbers, $\chi$ represents the Rayleigh drag coefficient, $\beta$ represents the effect of beta-plane turbulence, and $\bm{u}=(u,v)$ is the velocity. In 2D, the velocity can be represented by stream function
#
# $$
# u = \frac{\partial \psi}{\partial y}, v = -\frac{\partial \psi}{\partial x},
# $$
#
# In DNS, governing equations are solved in a doubly periodic domain using a Fourier-Fourier pseudo-spectral solver with second-order Adams-Bashforth and Crank Nicholson time-integration schemes for the advection and viscous terms, respectively (time step $\Delta t_{\text{DNS}}$).
#
# For LES, we use the same solver with lower spatio-temporal resolution: We use $N_{\rm{LES}}$ that is 8 to 64 times smaller than $N_{\text{DNS}}$, and $\Delta t_{\text{LES}}=10\Delta t_{\text{DNS}}$.
#
# For LES, equations are derived by applying a homogenous filter to leading to,
#
# $$
# \begin{aligned}
#     \nabla^2\overline{\psi} &= -\overline{\omega}, \\
#     \frac{\partial \overline{\omega}}{\partial t} + \mathcal{N}(\overline{\omega},\overline{\psi}) &= \frac{1}{Re} \nabla^2\overline{\omega} -\chi\overline{\omega} - \overline{f} -\left(\overline{\mathcal{N}(\omega,\psi)}-\mathcal{N}(\overline{\omega},\overline{\psi}) \right),
# \end{aligned}
# $$
#
# $$
# \begin{aligned}
#     \Pi_{\omega} &= \nabla \times \nabla \cdot \bm{\tau} \\
#     &= \overline{\mathcal{N}(\omega,\psi)}-\mathcal{N}(\overline{\omega},\overline{\psi})
# \end{aligned}
# $$

# %% [markdown]
# ## Eddy Viscosity Models
# $$
# \Pi_{\omega} = - \nu_e \nabla^2 \overline{\omega},
# $$
# where $\nu$ is the eddy viscosity needs to be modeled
#
# ### Smagorinsky (SMAG)
# $$
# \nu_e = (C_s\Delta)^2 |\overline{\mathcal{S}}| \\
# \overline{\mathcal{S}} = \sqrt{2 \overline{S}_{ij} \overline{S}_{ij}} \\
# \overline{S}_{ij} = \frac{1}{2} \left(\frac{\partial \overline{u}_i}{\partial x_j} + \frac{\partial \overline{u}_j}{\partial x_i} \right)
# $$
# Here $C_s$ is the SMAG coefficient or eddy viscosity coefficient and $\Delta$ is the filter width.
#
# ### LEITH
# $$
# \nu_e = (C_L\Delta)^3 |\nabla \overline{\omega}| \\
# $$
# Here $C_L$ is the LEITH coefficient or eddy viscosity coefficient.

# %%
# Import the Py2D_solver function from the py2d.Py2D_solver module
from py2d.Py2D_solver import Py2D_solver
# Import the numpy library for numerical operations
import numpy as np

# The code saves the snapshots of Omega in the folder: result/

# Initialize a flag to control whether to resume a simulation
resumeSimulation = False
# Set an initial value for the eddy viscosity coefficient
eddyViscosityCoeff_temp = 0.17

# Loop through 10 iterations to update the simulation
for count in range(10):

    # For iterations after the first one
    if count > 0:
        # Set the flag to resume the simulation from the last saved state
        resumeSimulation = True

        # Update the eddy viscosity coefficient after running the solver for a few iterations
        # Here, it's simply incremented by 0.01 from its initial value
        eddyViscosityCoeff_temp = 0.17 + 0.01

    # Call the Py2D_solver function with specified parameters
    Omega = Py2D_solver(
        Re=20e3,  # Reynolds number
        fkx=4,  # Forcing wavenumber in x
        fky=4,  # Forcing wavenumber in y
        alpha=0.1,  # Rayleigh drag coefficient
        beta=0,  # Coriolis parameter
        NX=128,  # Number of grid points in x and y (options: 32, 64, 128, 256, 512)
        SGSModel_string='LEITH',  # SGS model to use (options: 'NoSGS', 'SMAG', 'DSMAG', 'LEITH', etc.)
        eddyViscosityCoeff=eddyViscosityCoeff_temp,  # Coefficient for eddy viscosity models
        dt=5e-4,  # Time step
        saveData=True,  # Flag to save data
        tSAVE=0.001,  # Time interval to save data
        tTotal=0.01,  # Total time of simulation
        readTrue=False, 
        ICnum=1,  # Initial condition number (options: 1 to 20)
        resumeSim=resumeSimulation,  # Flag to start a new simulation or resume an existing one
    )

    # Print the domain average of enstrophy, calculated as the mean of the square of Omega
    print(np.mean(Omega**2))
# Out:
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          | False  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                               0.17                              |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                               0.17                              |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: None
# Updated last data file number to 0
# Last data file number: None
# Updated last data file number to 0
# Parameters of the flow saved to saved to results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/parameter.txt
# -------------- Main iteration loop --------------
# Time = 0.001000 -- Eddy Turnover Time = 0.236958 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/1
# Time = 0.002000 -- Eddy Turnover Time = 0.236942 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/2
# Time = 0.003000 -- Eddy Turnover Time = 0.236925 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/3
# Time = 0.004000 -- Eddy Turnover Time = 0.236908 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/4
# Time = 0.005000 -- Eddy Turnover Time = 0.236892 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/5
# Time = 0.006000 -- Eddy Turnover Time = 0.236875 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/6
# Time = 0.007000 -- Eddy Turnover Time = 0.236857 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/7
# Time = 0.008000 -- Eddy Turnover Time = 0.236840 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/8
# Time = 0.009000 -- Eddy Turnover Time = 0.236823 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/9
# Time = 0.010000 -- Eddy Turnover Time = 0.236805 -- C = 0.1700 -- Eddy viscosity = 0.000158 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/10
# Total Iteration:  20
# Total Time Taken:  27.889423935994273
# 17.832692141762728
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 10
# Last IC file number: 10
# -------------- Main iteration loop --------------
# Time = 0.010000 -- Eddy Turnover Time = 0.236806 -- C = 0.1800 -- Eddy viscosity = 0.000187 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/10
# Time = 0.011000 -- Eddy Turnover Time = 0.236789 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/11
# Time = 0.012000 -- Eddy Turnover Time = 0.236772 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/12
# Time = 0.013000 -- Eddy Turnover Time = 0.236755 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/13
# Time = 0.014000 -- Eddy Turnover Time = 0.236738 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/14
# Time = 0.015000 -- Eddy Turnover Time = 0.236721 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/15
# Time = 0.016000 -- Eddy Turnover Time = 0.236704 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/16
# Time = 0.017000 -- Eddy Turnover Time = 0.236686 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/17
# Time = 0.018000 -- Eddy Turnover Time = 0.236668 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/18
# Time = 0.019000 -- Eddy Turnover Time = 0.236651 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/19
# Total Iteration:  20
# Total Time Taken:  28.002717302995734
# 17.856002875946853
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 19
# Last IC file number: 19
# -------------- Main iteration loop --------------
# Time = 0.019000 -- Eddy Turnover Time = 0.236651 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/19
# Time = 0.020000 -- Eddy Turnover Time = 0.236633 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/20
# Time = 0.021000 -- Eddy Turnover Time = 0.236615 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/21
# Time = 0.022000 -- Eddy Turnover Time = 0.236597 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/22
# Time = 0.023000 -- Eddy Turnover Time = 0.236579 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/23
# Time = 0.024000 -- Eddy Turnover Time = 0.236561 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/24
# Time = 0.025000 -- Eddy Turnover Time = 0.236542 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/25
# Time = 0.026000 -- Eddy Turnover Time = 0.236524 -- C = 0.1800 -- Eddy viscosity = 0.000188 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/26
# Time = 0.027000 -- Eddy Turnover Time = 0.236505 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/27
# Time = 0.028000 -- Eddy Turnover Time = 0.236487 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/28
# Total Iteration:  20
# Total Time Taken:  28.10922416199901
# 17.880806344570086
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 28
# Last IC file number: 28
# -------------- Main iteration loop --------------
# Time = 0.028000 -- Eddy Turnover Time = 0.236487 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/28
# Time = 0.029000 -- Eddy Turnover Time = 0.236468 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/29
# Time = 0.030000 -- Eddy Turnover Time = 0.236449 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/30
# Time = 0.031000 -- Eddy Turnover Time = 0.236430 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/31
# Time = 0.032000 -- Eddy Turnover Time = 0.236411 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/32
# Time = 0.033000 -- Eddy Turnover Time = 0.236392 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/33
# Time = 0.034000 -- Eddy Turnover Time = 0.236372 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/34
# Time = 0.035000 -- Eddy Turnover Time = 0.236353 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/35
# Time = 0.036000 -- Eddy Turnover Time = 0.236333 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/36
# Time = 0.037000 -- Eddy Turnover Time = 0.236314 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/37
# Total Iteration:  20
# Total Time Taken:  28.21415828300087
# 17.90698106547639
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 37
# Last IC file number: 37
# -------------- Main iteration loop --------------
# Time = 0.037000 -- Eddy Turnover Time = 0.236314 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/37
# Time = 0.038000 -- Eddy Turnover Time = 0.236294 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/38
# Time = 0.039000 -- Eddy Turnover Time = 0.236274 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/39
# Time = 0.040000 -- Eddy Turnover Time = 0.236254 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/40
# Time = 0.041000 -- Eddy Turnover Time = 0.236234 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/41
# Time = 0.042000 -- Eddy Turnover Time = 0.236214 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/42
# Time = 0.043000 -- Eddy Turnover Time = 0.236194 -- C = 0.1800 -- Eddy viscosity = 0.000189 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/43
# Time = 0.044000 -- Eddy Turnover Time = 0.236173 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/44
# Time = 0.045000 -- Eddy Turnover Time = 0.236153 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/45
# Time = 0.046000 -- Eddy Turnover Time = 0.236132 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/46
# Total Iteration:  20
# Total Time Taken:  28.30601176899654
# 17.93451082960995
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 46
# Last IC file number: 46
# -------------- Main iteration loop --------------
# Time = 0.046000 -- Eddy Turnover Time = 0.236132 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/46
# Time = 0.047000 -- Eddy Turnover Time = 0.236112 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/47
# Time = 0.048000 -- Eddy Turnover Time = 0.236091 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/48
# Time = 0.049000 -- Eddy Turnover Time = 0.236070 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/49
# Time = 0.050000 -- Eddy Turnover Time = 0.236049 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/50
# Time = 0.051000 -- Eddy Turnover Time = 0.236028 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/51
# Time = 0.052000 -- Eddy Turnover Time = 0.236007 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/52
# Time = 0.053000 -- Eddy Turnover Time = 0.235985 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/53
# Time = 0.054000 -- Eddy Turnover Time = 0.235964 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/54
# Time = 0.055000 -- Eddy Turnover Time = 0.235942 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/55
# Total Iteration:  20
# Total Time Taken:  28.402252035994024
# 17.96338226046236
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 55
# Last IC file number: 55
# -------------- Main iteration loop --------------
# Time = 0.055000 -- Eddy Turnover Time = 0.235942 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/55
# Time = 0.056000 -- Eddy Turnover Time = 0.235921 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/56
# Time = 0.057000 -- Eddy Turnover Time = 0.235899 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/57
# Time = 0.058000 -- Eddy Turnover Time = 0.235877 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/58
# Time = 0.059000 -- Eddy Turnover Time = 0.235855 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/59
# Time = 0.060000 -- Eddy Turnover Time = 0.235833 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/60
# Time = 0.061000 -- Eddy Turnover Time = 0.235811 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/61
# Time = 0.062000 -- Eddy Turnover Time = 0.235789 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/62
# Time = 0.063000 -- Eddy Turnover Time = 0.235767 -- C = 0.1800 -- Eddy viscosity = 0.000190 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/63
# Time = 0.064000 -- Eddy Turnover Time = 0.235744 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/64
# Total Iteration:  20
# Total Time Taken:  28.49555886899907
# 17.99357072856398
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 64
# Last IC file number: 64
# -------------- Main iteration loop --------------
# Time = 0.064000 -- Eddy Turnover Time = 0.235744 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/64
# Time = 0.065000 -- Eddy Turnover Time = 0.235722 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/65
# Time = 0.066000 -- Eddy Turnover Time = 0.235699 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/66
# Time = 0.067000 -- Eddy Turnover Time = 0.235677 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/67
# Time = 0.068000 -- Eddy Turnover Time = 0.235654 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/68
# Time = 0.069000 -- Eddy Turnover Time = 0.235631 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/69
# Time = 0.070000 -- Eddy Turnover Time = 0.235608 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/70
# Time = 0.071000 -- Eddy Turnover Time = 0.235585 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/71
# Time = 0.072000 -- Eddy Turnover Time = 0.235562 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/72
# Time = 0.073000 -- Eddy Turnover Time = 0.235538 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/73
# Total Iteration:  20
# Total Time Taken:  28.58607800399477
# 18.0250443208728
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 73
# Last IC file number: 73
# -------------- Main iteration loop --------------
# Time = 0.073000 -- Eddy Turnover Time = 0.235538 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/73
# Time = 0.074000 -- Eddy Turnover Time = 0.235515 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/74
# Time = 0.075000 -- Eddy Turnover Time = 0.235492 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/75
# Time = 0.076000 -- Eddy Turnover Time = 0.235468 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/76
# Time = 0.077000 -- Eddy Turnover Time = 0.235444 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/77
# Time = 0.078000 -- Eddy Turnover Time = 0.235421 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/78
# Time = 0.079000 -- Eddy Turnover Time = 0.235397 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/79
# Time = 0.080000 -- Eddy Turnover Time = 0.235373 -- C = 0.1800 -- Eddy viscosity = 0.000191 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/80
# Time = 0.081000 -- Eddy Turnover Time = 0.235349 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/81
# Time = 0.082000 -- Eddy Turnover Time = 0.235325 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/82
# Total Iteration:  20
# Total Time Taken:  28.676771843995084
# 18.057766475512924
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# [Errno 17] File exists: 'results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/'
# +--------------------------------------------------------------------+--------+
# |                         Run Configuration                          | Value  |
# +--------------------------------------------------------------------+--------+
# |                           Time Step (dt)                           | 0.0005 |
# |                         Resume Simulation                          |  True  |
# | Read Initialization (readTrue), If False: Will read IC from a file | False  |
# |                      Saving Data  (saveData)                       |  True  |
# |               Save data every t th timestep (tSAVE)                | 0.001  |
# |               Save data every Nth iteration (NSAVE)                |   2    |
# |                   Length of simulation (tTotal)                    |  0.01  |
# |                Maximum Number of Iterations (maxit)                |   20   |
# +--------------------------------------------------------------------+--------+
#
# +----------------------------+---------------------+
# |     Geometry and Mesh      |        Value        |
# +----------------------------+---------------------+
# | Number of Grid Points (NX) |         128         |
# |     Domain Length (L)      |  6.283185307179586  |
# |       Mesh size (dx)       | 0.04908738521234052 |
# +----------------------------+---------------------+
#
# +-------------------------------------------------+-----------------------------------------------------------------+
# |                Geometry and Mesh                |                              Value                              |
# +-------------------------------------------------+-----------------------------------------------------------------+
# |               Reynolds Number (Re)              |                             20000.0                             |
# |      Deterministic Forcing Wavenumber (fkx)     |                                4                                |
# |      Deterministic Forcing Wavenumber (fky)     |                                4                                |
# |         Linear Drag Coefficient (alpha)         |                               0.1                               |
# |           Beta plan coefficient (beta)          |                                0                                |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                    SGS Model                    |                              LEITH                              |
# | Eddy Viscosity Coefficient (eddyViscosityCoeff) |                       0.18000000000000002                       |
# |                 Saving Directory                | results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/ |
# +-------------------------------------------------+-----------------------------------------------------------------+
#
# -------------- Initialization Section--------------
# Last data file number: 82
# Last IC file number: 82
# -------------- Main iteration loop --------------
# Time = 0.082000 -- Eddy Turnover Time = 0.235325 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/82
# Time = 0.083000 -- Eddy Turnover Time = 0.235301 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/83
# Time = 0.084000 -- Eddy Turnover Time = 0.235277 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/84
# Time = 0.085000 -- Eddy Turnover Time = 0.235252 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/85
# Time = 0.086000 -- Eddy Turnover Time = 0.235228 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/86
# Time = 0.087000 -- Eddy Turnover Time = 0.235203 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/87
# Time = 0.088000 -- Eddy Turnover Time = 0.235179 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/88
# Time = 0.089000 -- Eddy Turnover Time = 0.235154 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/89
# Time = 0.090000 -- Eddy Turnover Time = 0.235129 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/90
# Time = 0.091000 -- Eddy Turnover Time = 0.235104 -- C = 0.1800 -- Eddy viscosity = 0.000192 ** Saved results/Re20000_fkx4fky4_r0.1_b0/LEITH/NX128/dt0.0005_IC1/data/91
# Total Iteration:  20
# Total Time Taken:  28.77050075099396
# 18.091697620095452
